# %%
# %matplotlib nbagg 
#%matplotlib inline
#%matplotlib ipympl
#%matplotlib widget

# %load_ext autoreload
# %autoreload 2
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import matplotlib.pyplot as plt 
import numpy as np  # numerics
import math as math  # math
import nd2 as nd2
import os as os
from skimage.filters import threshold_otsu, threshold_li,threshold_yen,threshold_niblack,threshold_sauvola
from tqdm import tqdm
import skimage as ski

from skimage.morphology import binary_dilation, binary_erosion
from skimage.measure import label, regionprops
from skimage.segmentation import flood_fill
from src.ContourUtils import *
# Out:
# <style>.container { width:100% !important; }</style>

# %%
folder = "/home/tom/data_lagrin/Thomas/LineExtract_problematic_files/"
ls = os.listdir(folder)
ls_filtered = []
for i in ls:
    if (".nd2" in i and "BF" not in i):
        ls_filtered.append(i)

# %%
img = nd2.imread(folder+ls_filtered[1])
print(ls_filtered[1])
print(img.shape)
# Out:
# Right_GFP_RFP_x4010.nd2
# (2, 2720, 2720)

# %%
print(img.shape)
img = np.amax(img,axis=0)

print(img.shape)
# Out:
# (2, 2720, 2720)
# (2720, 2720)

# %%
plt.figure()
ax= plt.subplot(221)
plt.imshow(img[1])
plt.subplot(222,sharex=ax,sharey=ax)
plt.imshow(img[1])

plt.subplot(223,sharex=ax,sharey=ax)
plt.imshow(img>threshold_li(img))
print(threshold_li(img))

plt.subplot(224,sharex=ax,sharey=ax)
plt.imshow(img[1]>threshold_otsu(img[1]))

plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 plt.figure()
#       2 ax= plt.subplot(221)
# ----> 3 plt.imshow(img[1])
#       4 plt.subplot(222,sharex=ax,sharey=ax)
#       5 plt.imshow(img[1])
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:3593, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3571 @_copy_docstring_and_deprecators(Axes.imshow)
#    3572 def imshow(
#    3573     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3591     **kwargs,
#    3592 ) -> AxesImage:
# -> 3593     __ret = gca().imshow(
#    3594         X,
#    3595         cmap=cmap,
#    3596         norm=norm,
#    3597         aspect=aspect,
#    3598         interpolation=interpolation,
#    3599         alpha=alpha,
# ...

# %%
thresholded = img[0]>threshold_li(img[0])

N_dilation = 3
for i in range(N_dilation):
    thresholded = binary_dilation(thresholded)

# %%
contour = np.bitwise_xor(binary_dilation(thresholded),thresholded)

# %%
plt.figure()
lab = label(contour)

max_size = 0
for i in range(1,np.amax(lab)):
    if (np.sum(lab == i) > max_size):
        max_size = np.sum(lab==i)
        idx = i
        
plt.imshow(img[0],cmap="gist_gray",vmin=100,vmax=400)
plt.colorbar()
plt.imshow(lab==idx,alpha=0.4)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 plt.figure()
# ----> 2 lab = label(contour)
#       4 max_size = 0
#       5 for i in range(1,np.amax(lab)):
#
# NameError: name 'contour' is not defined

# %%
## Flood to clean the contour

#fill = flood_fill(lab==idx,(1500,1500),1,connectivity=1)
fill = flood_fill(thresholded,(1500,1500),1,connectivity=1)

# %%
plt.figure()
plt.imshow(fill)

# %%
contour_final = np.bitwise_xor(binary_dilation(fill),fill)

# %%
plt.figure()
plt.imshow(img[1],cmap="gist_gray",vmin=100,vmax=600)
plt.imshow(contour_final,alpha=.4,cmap="inferno")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 plt.figure()
#       2 plt.imshow(img[1],cmap="gist_gray",vmin=100,vmax=600)
# ----> 3 plt.imshow(contour_final,alpha=.4,cmap="inferno")
#
# NameError: name 'contour_final' is not defined
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(img.shape)
# Out:
# (2, 2720, 2720)

# %%
tt,fill = make_contour_mask(img[0])
tt2,fill2 = make_contour_mask(img[1])
# Out:
# Labelling
# Finding the biggest contour
# Flood fill
# Labelling
# Finding the biggest contour
# Flood fill
# Cleaning
# Labelling
# Finding the biggest contour
# Flood fill
# Labelling
# Finding the biggest contour
# Flood fill
# Cleaning

# %%
plt.figure()
plt.imshow(img[0],cmap="gist_gray",vmax=1000)
#plt.imshow(((tt)),cmap="inferno",alpha = .4)
#plt.imshow(np.bitwise_not(fill))

# %%
from src.fractal_dimension import *

# %%
dim, ss, cc = fractal_dimension(fill,return_coeffs=True)
dim2, ss2, cc2 = fractal_dimension(fill2,return_coeffs=True)

# %%
plt.figure()
plt.plot(ss,cc,label = str(dim))
plt.plot(ss2,cc2,label = str(dim2))
#plt.title(dim)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.imshow(img[0],cmap="gist_gray",vmax=1000)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(get_migration_index(tt))

# %% [markdown]
# ## Optimizing the function for edge cases

# %%
def make_contour_mask(img):
    """ Expects a MIP fluo img"""

    thresholded = img>threshold_li(img)
    dilated = thresholded.copy()
    
    connected_contour_flag = False
    
    while not (connected_contour_flag):
        
        contour = np.bitwise_xor(binary_dilation(dilated), dilated)

        print("Labelling")
        lab = label(contour)

        max_size = 0
        candidates = []
        print("Finding the biggest contour")
        for i in range(1,np.amax(lab)):
            sub_contour = lab==i
            
            if (np.sum(sub_contour[0]) >0 and np.sum(sub_contour[len(sub_contour)-1] > 0)): #checking that it connects top and bottom$
                if (get_migration_index(sub_contour)<5):
                    candidates.append(i)
                
        print("Flood fill")

        if (len(candidates) > 0):
            connected_contour_flag = True
        
        dilated = binary_dilation(dilated)

    tentative_contour = lab==candidates[0]      
    tentative_contour = np.array(tentative_contour,dtype=int)
    fill = flood_fill(tentative_contour,(int(len(img)/2),int(len(img[0])/2)),2,connectivity=1)
    fill = fill==2
        

    print("Cleaning")
    contour_final = np.bitwise_xor(binary_dilation(fill),fill)
    return contour_final,fill



def get_contour_end_points(contour):
    top = np.where(contour[0])[0][0]
    bottom = np.where(contour[len(contour)-1])[0][0]
    return top,bottom


def get_migration_index(contour):
    top,bottom = get_contour_end_points(contour)
    delta_y_squared = len(contour)**2
    base_distance = np.sqrt((top - bottom)**2 + delta_y_squared)
    
    return np.sum(contour)/base_distance

def get_contour_distances(contour):
    top,bottom = get_contour_end_points(contour)
    delta_y_squared = len(contour)**2
    base_distance = np.sqrt((top - bottom)**2 + delta_y_squared)
    
    return base_distance,np.sum(contour)

# %%
contour_vanilla = make_contour_mask(img[0])

# %%
plt.figure()
plt.imshow(img[0],vmax=2000)
plt.colorbar()


plt.contour(contour_vanilla[0],alpha=1,colors="white",levels=[.5],linewidths=.5)
# Out:
# <img src="data:image/png;base64,..." width="1291">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 6
#       2 plt.imshow(img[0],vmax=2000)
#       3 plt.colorbar()
# ----> 6 plt.contour(contour_vanilla[0],alpha=1,colors="white",levels=[.5],linewidths=.5)
#
# NameError: name 'contour_vanilla' is not defined

# %%
print(line_overlay)

# %% [markdown]
# ## 2025_11_13 Edge cases correction

# %%
N = 2
print(ls_filtered[N])
img = nd2.imread(folder+ls_filtered[N])
img = np.amax(img,axis=0) # MIP
if (img.ndim == 2):
    img = np.array([img])



print(img.shape)
#for j in range(len(img)): ## loop on channels
img = img[0]

contour,fill,tests = make_contour_mask(img, "otsu")



    #plt.imshow(img[j],cmap="gist_gray")
    #plt.imshow(contour,cmap="inferno",alpha=.7)
    #plt.contour(contour,colors="white",levels=[.5],linewidths=.5)
# Out:
# Day9_Plate1_Chip3_Right.nd2
# (2, 2720, 2720)
# Left
# Labelling
# Finding the biggest contour
# C1:  15
# Labelling
# Finding the biggest contour
# C1:  15
# Labelling
# Finding the biggest contour
# C1:  11
# Labelling
# Finding the biggest contour
# C1:  12
# Labelling
# Finding the biggest contour
# C1:  12
# C2:  12
# Labelling
# Finding the biggest contour
# C1:  10
# C2:  10
# Labelling
# Finding the biggest contour
# C1:  8
# C2:  8
# Labelling
# Finding the biggest contour
# C1:  7
# C2:  7
# Labelling
# Finding the biggest contour
# C1:  7
# C2:  7
# Labelling
# Finding the biggest contour
# C1:  9
# C2:  9
# Labelling
# Finding the biggest contour
# C1:  6
# C2:  6
# Labelling
# Finding the biggest contour
# C1:  7
# C2:  7
# Labelling
# Finding the biggest contour
# C1:  12
# C2:  12
# Labelling
# Finding the biggest contour
# C1:  12
# C2:  12
# Labelling
# Finding the biggest contour
# C1:  10
# C2:  10
# Labelling
# Finding the biggest contour
# C1:  9
# C2:  9
# ...

# %%
plt.figure()
ax = plt.subplot(121)
plt.imshow(tests[0])
plt.subplot(122,sharex=ax,sharey=ax)
plt.imshow(tests[1])
# Out:
# <img src="data:image/png;base64,..." width="1426">

# %%
for i in range(len(ls_filtered)):
    print(i,ls_filtered[i])
N = 5
print(ls_filtered[N])

img = nd2.imread(folder+ls_filtered[N])
img = np.amax(img,axis=0) # MIP
if (img.ndim == 2):
    img = np.array([img])

    
img = img[0]
# Out:
# 0 Day6_Plate2_Chip5_Left.nd2
# 1 Right_GFP_RFP_x4012.nd2
# 2 Day9_Plate1_Chip3_Right.nd2
# 3 Right_GFP_RFP_x4010.nd2
# 4 Day6_Plate2_Chip5_Right.nd2
# 5 Day9_Plate2_Chip5_Right.nd2
# 6 Day9_Plate1_Chip4_Left.nd2
# 7 Right_GFP_RFP_x4008.nd2
# 8 Day9_Plate1_Chip4_Right.nd2
# 9 Day9_Plate2_Chip5_Left.nd2
# Day9_Plate2_Chip5_Right.nd2

# %%
thresholded = img>threshold_otsu(img)
dilated = thresholded.copy()

connected_contour_flag = False
N_it = 0


#contour = np.bitwise_xor(binary_dilation(dilated), dilated)
contour = np.bitwise_xor(binary_erosion(dilated), dilated)
lab = label(contour)

candidates = []
print("Finding the biggest contour")
for i in range(1,np.amax(lab)):
    sub_contour = lab==i

    if (np.sum(sub_contour[0]) >0 and np.sum(sub_contour[len(sub_contour)-1] > 0)): #checking that it connects top and bottom$
        candidates.append(i)
# Out:
# Finding the biggest contour

# %%
print(candidates)

tentative_contour = lab==25
fill = flood_fill(tentative_contour,(int(len(img)/2),len(img[0])-1),2,connectivity=1)


plt.figure()
plt.imshow(img, cmap="inferno")
# Out:
# [25]
# <img src="data:image/png;base64,..." width="1627">

# %%
plt.figure()
plt.imshow(lab==15)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="1611">

# %%
print(np.where(tentative_contour==True)[1])
print(np.unravel_index(1510,tentative_contour.shape))

print()
plt.figure()
plt.imshow(tentative_contour)
# Out:
# [1510 1511 1513 ... 1679 1683 1678]
# (0, 1510)
# <img src="data:image/png;base64,..." width="640">

# %%
thresholded = img>(threshold_li(img)+threshold_otsu(img))/2
thresholded2 = img> threshold_otsu(img)
thresholded3 = img > np.mean(img)

print(threshold_li(img),threshold_otsu(img), np.mean(img),np.std(img))

plt.figure(figsize=(30,15))
plt.subplot(131)
plt.imshow(thresholded)
#plt.imshow(lab==1)

plt.subplot(132)
plt.imshow(thresholded3)

plt.subplot(133)
plt.imshow(img)

1130/344
# Out:
# /home/tom/prog/HTH_LineExtract/src/ContourUtils.py:62: SyntaxWarning: invalid escape sequence '\ '
#   print("/!\ Aborted")
# 117.65612583846287 122 109.03834558823529 12.083626088699654
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       7 plt.figure(figsize=(30,15))
#       8 plt.subplot(131)
# ----> 9 plt.imshow(thresholded)
#      10 #plt.imshow(lab==1)
#      12 plt.subplot(132)
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:3593, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3571 @_copy_docstring_and_deprecators(Axes.imshow)
#    3572 def imshow(
#    3573     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3591     **kwargs,
#    3592 ) -> AxesImage:
# -> 3593     __ret = gca().imshow(
#    3594         X,
# ...

# %%
#plt.figure(figsize=(20,20))

fig, ax = ski.filters.try_all_threshold(img, figsize=(20,20), verbose=False)
# Out:
# <img src="data:image/png;base64,..." width="2000">

# %%
plt.figure(figsize=(15,15))
plt.hist(img.flatten(),bins=100)
plt.axvline(threshold_otsu(img))
plt.axvline(threshold_li(img))
#plt.axvline(threshold_niblack(img))
print(threshold_niblack(img))
#plt.axvline(threshold_sauvola(img))
print(threshold_sauvola(img))
# Out:
# <img src="data:image/png;base64,..." width="1500">
# [[[331.1787455  331.64395949 334.86285538 ... 151.2455863  151.37938809
#    151.53355318]
#   [332.2023796  332.65437348 335.91122504 ... 150.88698315 151.05723844
#    151.1389167 ]
#   [334.42661356 334.9027778  338.08573687 ... 150.64137155 150.95570315
#    150.97355944]
#   ...
#   [258.87228134 259.61414782 259.14500614 ... 145.47394695 145.759281
#    145.9475314 ]
#   [259.74053327 260.54537106 259.84044305 ... 145.31041853 145.65099416
#    145.87213846]
#   [259.30166221 259.93916877 259.24098811 ... 145.5060144  145.80930108
#    146.02748445]]
#
#  [[367.36736348 367.95325365 371.7082788  ... 148.77457886 148.94093339
#    149.08371466]
#   [368.61263917 369.16419437 372.96761691 ... 148.4555367  148.6465986
#    148.70831447]
#   [371.14441564 371.73239986 375.44847833 ... 148.23132171 148.5493794
#    148.54763392]
#   ...
#   [282.12328335 282.94045432 282.37675299 ... 144.08209705 144.35613878
#    144.54137905]
# ...
